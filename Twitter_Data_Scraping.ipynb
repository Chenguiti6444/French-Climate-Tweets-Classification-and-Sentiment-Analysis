# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# set the search query
query = "(réchauffement climatique OR sécheresse) lang:fr"
tweets = []
limit = 20000

# scrape tweets
for tweet in sntwitter.TwitterSearchScraper(query).get_items():

    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])

# create a pandas dataframe from the scraped data
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])

# Ajout d'une colonne pour stocker la polarité
df['polarity'] = 0.0
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10564\3908469484.py:19: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10564\3908469484.py:19: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])

# %%
# Save the dataframe to a CSV file
df.to_csv('tweets.csv', index=False)
